# %% [markdown]
# <a href="https://colab.research.google.com/github/Ricardo-Medeiros/Projeto-Rick_Tech/blob/main/Untitled5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def livro(nome, qtdPaginas, autor, preco):

  print("Detalhes do Livro:")
  print(f"Nome: {nome}")
  print(f"Quantidade de Páginas: {qtdPaginas}")
  print(f"Autor: {autor}")
  print(f"Preço: R${preco:.2f}")

def menu():

  print("Por favor, insira as informações do livro:")
  nome_livro = input("Nome do livro: ")
  qtd_paginas_livro = int(input("Quantidade de páginas: "))
  autor_livro = input("Autor do livro: ")
  preco_str = input("Preço do livro: ")
  preco_livro = float(preco_str.replace(',', '.'))

  livro(nome_livro, qtd_pagina, autor_livro, preco_livro)

# %%
#Programa que recebe do usúario o nome do aluno e matricula, retornando informações na tela

nome = input("Digite seu nome: ")
matricula = int(input("Digite sua matricula: "))

print("Deseja alterar algum dado do seu cadastro? ")
print("1 - Sim")
print("2 - Não")
opcao = int(input())

if opcao == 1:
  print("Qual dado você deseja alterar? ")
  print("1 - Nome")
  print("2 - Matrícula")
  opcao = int(input())
  if opcao == 1:
    nome = input("Digite seu nome: ")
    print("Nome alterado com sucesso!")

  elif opcao == 2:
    matricula = int(input("Digite sua matricula: "))
    print("Matrícula alterada com sucesso!")
# Out:
# Digite seu nome: Ricardo
# Digite sua matricula: 123
# Deseja alterar algum dado do seu cadastro?
# 1 - Sim
# 2 - Não
# 1
# Qual dado você deseja alterar?
# 1 - Nome
# 2 - Matrícula
# 1
# Digite seu nome: Loud
# Nome alterado com sucesso!

# %%
#Programa que tem 3 funções, soma de tres numeros, funçao de media que irá receber a função soma e a terceira funçao sera de menu para receber o numero dos usuarios

def soma(num1, num2, num3):
  soma = num1 + num2 + num3
  return soma

  def media(soma):
    media = soma / 3
    return media

    def menu():
      print("Escolha uma opção: ")
      print("1 - Somar")
      print("2 - Média")
      print("3 - Sair")
      opcao = int(input())
      return opcao
      while True:
          num1 = int(input("Digite o primeiro número: "))
          num2 = int(input("Digite o segundo número: "))
          num3 = int(input("Digite o terceiro número: "))
          opcao = menu()
          if opcao == 1:
            soma = soma(num1, num2, num3)
            print("A soma é: ")
          elif opcao == 2:
            media = media(soma)
            print("A média é: ")
